# %%
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os

# %%
model=VGG16()
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for file in os.listdir('c:/Users/MD SANOWAR HOSSAIN/Downloads/archive/asl_alphabet_test/asl_alphabet_test'):
    print(file)
    full_path = 'c:/Users/MD SANOWAR HOSSAIN/Downloads/archive/asl_alphabet_test/asl_alphabet_test/' + file
    
    image = load_img(full_path, target_size=(224,224))
    image = img_to_array(image)
    image = image.reshape(1, image.shape[0], image.shape[1], image.shape[2])
    
    image = preprocess_input(image)
    y_pred = model.predict(image)
    label= decode_predictions(y_pred)
    print(label)
    print()
# Out:
# A_test.jpg
# WARNING:tensorflow:From E:\anaconda\lib\site-packages\tensorflow\python\ops\array_ops.py:5069: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# [[('n04404412', 'television', 0.21089333), ('n03529860', 'home_theater', 0.060960695), ('n03782006', 'monitor', 0.044338703), ('n02977058', 'cash_machine', 0.041574575), ('n02777292', 'balance_beam', 0.031081518)]]
#
# B_test.jpg
# [[('n04404412', 'television', 0.17404227), ('n03529860', 'home_theater', 0.06480308), ('n04152593', 'screen', 0.052909628), ('n03782006', 'monitor', 0.04879579), ('n02977058', 'cash_machine', 0.02978499)]]
#
# C_test.jpg
# [[('n04404412', 'television', 0.18716416), ('n03782006', 'monitor', 0.14165884), ('n04152593', 'screen', 0.10292149), ('n06359193', 'web_site', 0.08585666), ('n02077923', 'sea_lion', 0.03370168)]]
#
# D_test.jpg
# [[('n04404412', 'television', 0.05504522), ('n06359193', 'web_site', 0.044459928), ('n03782006', 'monitor', 0.038605615), ('n03532672', 'hook', 0.037885696), ('n04152593', 'screen', 0.03535625)]]
#
# E_test.jpg
# [[('n04404412', 'television', 0.15408358), ('n04152593', 'screen', 0.09140079), ('n03782006', 'monitor', 0.0897669), ('n06359193', 'web_site', 0.07606319), ('n02977058', 'cash_machine', 0.05552132)]]
#
# F_test.jpg
# [[('n06359193', 'web_site', 0.1940482), ('n07695742', 'pretzel', 0.12962072), ('n04404412', 'television', 0.03859238), ('n04540053', 'volleyball', 0.03163357), ('n07248320', 'book_jacket', 0.02596663)]]
#
# G_test.jpg
# [[('n04404412', 'television', 0.08663311), ('n06359193', 'web_site', 0.07201406), ('n03876231', 'paintbrush', 0.040851656), ('n03804744', 'nail', 0.032512322), ('n02977058', 'cash_machine', 0.027384112)]]
#
# H_test.jpg
# [[('n04033901', 'quill', 0.18798035), ('n06359193', 'web_site', 0.078627504), ('n04404412', 'television', 0.060254097), ('n03782006', 'monitor', 0.045390774), ('n02977058', 'cash_machine', 0.04331381)]]
#
# I_test.jpg
# [[('n04404412', 'television', 0.17780514), ('n04152593', 'screen', 0.086148635), ('n03485407', 'hand-held_computer', 0.07415574), ('n03782006', 'monitor', 0.07036348), ('n03584254', 'iPod', 0.057637714)]]
#
# J_test.jpg
# [[('n04404412', 'television', 0.17992276), ('n03782006', 'monitor', 0.094311185), ('n04152593', 'screen', 0.070601664), ('n06359193', 'web_site', 0.059053645), ('n03529860', 'home_theater', 0.041701768)]]
#
# K_test.jpg
# [[('n02977058', 'cash_machine', 0.11177609), ('n04404412', 'television', 0.1116326), ('n06359193', 'web_site', 0.106753655), ('n04152593', 'screen', 0.06765799), ('n03485407', 'hand-held_computer', 0.06315359)]]
#
# L_test.jpg
# [[('n04404412', 'television', 0.110352814), ('n04152593', 'screen', 0.08620019), ('n03782006', 'monitor', 0.06852256), ('n06359193', 'web_site', 0.06343296), ('n02777292', 'balance_beam', 0.060304455)]]
#
# M_test.jpg
# [[('n04404412', 'television', 0.11322267), ('n03529860', 'home_theater', 0.07873138), ('n03782006', 'monitor', 0.05298991), ('n03584254', 'iPod', 0.04225822), ('n06359193', 'web_site', 0.04218327)]]
#
# nothing_test.jpg
# [[('n03529860', 'home_theater', 0.10534882), ('n04404412', 'television', 0.093341984), ('n03782006', 'monitor', 0.09080003), ('n04201297', 'shoji', 0.07492693), ('n03291819', 'envelope', 0.051500622)]]
#
# N_test.jpg
# [[('n04404412', 'television', 0.120221086), ('n04442312', 'toaster', 0.032135267), ('n03908714', 'pencil_sharpener', 0.02750483), ('n06359193', 'web_site', 0.024470884), ('n07860988', 'dough', 0.02090627)]]
#
# O_test.jpg
# [[('n04404412', 'television', 0.082500495), ('n03544143', 'hourglass', 0.04603628), ('n06359193', 'web_site', 0.037388343), ('n04033901', 'quill', 0.025244042), ('n02437312', 'Arabian_camel', 0.022523042)]]
#
# P_test.jpg
# [[('n06359193', 'web_site', 0.07659954), ('n02777292', 'balance_beam', 0.07174992), ('n02999410', 'chain', 0.034257695), ('n03584829', 'iron', 0.029529331), ('n04404412', 'television', 0.026789935)]]
#
# Q_test.jpg
# [[('n04404412', 'television', 0.06155112), ('n06359193', 'web_site', 0.058409575), ('n01494475', 'hammerhead', 0.04232885), ('n03782006', 'monitor', 0.041341405), ('n03804744', 'nail', 0.039657723)]]
#
# R_test.jpg
# [[('n04404412', 'television', 0.1560605), ('n02977058', 'cash_machine', 0.08946311), ('n03485407', 'hand-held_computer', 0.06494046), ('n04152593', 'screen', 0.058688123), ('n03584254', 'iPod', 0.04521015)]]
#
# space_test.jpg
# [[('n04404412', 'television', 0.25174367), ('n03529860', 'home_theater', 0.22564931), ('n02777292', 'balance_beam', 0.11536431), ('n03782006', 'monitor', 0.0636566), ('n04152593', 'screen', 0.05069356)]]
#
# S_test.jpg
# [[('n04404412', 'television', 0.19300175), ('n03529860', 'home_theater', 0.10682412), ('n03782006', 'monitor', 0.094900444), ('n06359193', 'web_site', 0.05981496), ('n04152593', 'screen', 0.049690787)]]
#
# T_test.jpg
# [[('n04404412', 'television', 0.26264334), ('n03782006', 'monitor', 0.11819999), ('n02977058', 'cash_machine', 0.09915511), ('n03529860', 'home_theater', 0.082368605), ('n04152593', 'screen', 0.076228656)]]
#
# U_test.jpg
# [[('n04404412', 'television', 0.17334759), ('n02786058', 'Band_Aid', 0.119819276), ('n02977058', 'cash_machine', 0.08637381), ('n04152593', 'screen', 0.06647897), ('n03485407', 'hand-held_computer', 0.06496256)]]
#
# V_test.jpg
# [[('n04404412', 'television', 0.17911379), ('n02977058', 'cash_machine', 0.117583044), ('n04152593', 'screen', 0.07866323), ('n03529860', 'home_theater', 0.050889794), ('n03782006', 'monitor', 0.04840682)]]
#
# W_test.jpg
# [[('n02786058', 'Band_Aid', 0.10831101), ('n04118776', 'rule', 0.08135021), ('n04154565', 'screwdriver', 0.06360406), ('n02977058', 'cash_machine', 0.053679693), ('n03876231', 'paintbrush', 0.04615766)]]
#
# X_test.jpg
# [[('n04404412', 'television', 0.26499164), ('n02977058', 'cash_machine', 0.1194649), ('n03782006', 'monitor', 0.10712258), ('n03529860', 'home_theater', 0.08681506), ('n04152593', 'screen', 0.0848162)]]
#
# Y_test.jpg
# [[('n04404412', 'television', 0.30675444), ('n02977058', 'cash_machine', 0.105108894), ('n03782006', 'monitor', 0.059319735), ('n04152593', 'screen', 0.052127495), ('n06359193', 'web_site', 0.04906091)]]
#
# Z_test.jpg
# [[('n04404412', 'television', 0.2750027), ('n04152593', 'screen', 0.174718), ('n02977058', 'cash_machine', 0.12743644), ('n03782006', 'monitor', 0.09805804), ('n03529860', 'home_theater', 0.04405329)]]
